# %% [markdown]
# ## Uso de la api covid con pandas
# En esta práctica y la ad4 vamos a utilizar "pandas" una libreria para trabajar sobre los datos de covid19 y analizarlos desde la
# una api con información cuya URL es: https://covid19api.com/
#
# ## Instalación de la librería
# Para instalar la librería "pandas" usaremos la función "pip". La exclamación es necesaria para que se ejecute.

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\luisa\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\luisa\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\luisa\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\luisa\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\luisa\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# ## Configuración de pandas
# Para importar utilizaremos la convención "pd" como abreviatura para llamar a la librería.

# %%
import pandas as pd

# %% [markdown]
# ## Crear variables
# Las variables se asignan con el signo "=" y los escribimos entrecomillados por ser una cadena de carácteres.

# %%
miurl = "https://api.covid19api.com/countries"

# %%
miurl
# Out:
# 'https://api.covid19api.com/countries'

# %%
type (miurl)
# Out:
# str

# %% [markdown]
# ## Empieza la magia de pandas
# ### Creamos un dataframe
# La abreviatura que se emplea para dataframe es "df". Existe una función "read_json()" que lee el formato "json" (java script). Dentro del parentesis ponemos el formato de lo que queremos que lea el dataframe, que en este caso es nuestra url.

# %%
df = pd.read_json(miurl)

# %% [markdown]
# Para visualizar los datos llamamos al objeto. La información se nos muestra en una tabla que contiene 3 columnas y una fila de control de pandas que indica las entradas del dataframe.

# %%
df
# Out:
#            Country           Slug ISO2
# 0           Angola         angola   AO
# 1          Georgia        georgia   GE
# 2          Ireland        ireland   IE
# 3         Slovenia       slovenia   SI
# 4    French Guiana  french-guiana   GF
# ..             ...            ...  ...
# 243      Sri Lanka      sri-lanka   LK
# 244         Canada         canada   CA
# 245         Kuwait         kuwait   KW
# 246          Libya          libya   LY
# 247     Seychelles     seychelles   SC
#
# [248 rows x 3 columns]

# %% [markdown]
# ## Exploración de la tabla
# Para ver las entradas de la tabla (el número que se le ponga es la cantidad de datos que quieres visualizar tanto de los primeros datos como los últimos) utilizamos la función head o tail:

# %%
df.head (12)
# Out:
#            Country            Slug ISO2
# 0           Angola          angola   AO
# 1          Georgia         georgia   GE
# 2          Ireland         ireland   IE
# 3         Slovenia        slovenia   SI
# 4    French Guiana   french-guiana   GF
# 5             Guam            guam   GU
# 6          Lebanon         lebanon   LB
# 7      Puerto Rico     puerto-rico   PR
# 8             Togo            togo   TG
# 9   American Samoa  american-samoa   AS
# 10   Guinea-Bissau   guinea-bissau   GW
# 11     Isle of Man     isle-of-man   IM

# %%
df.tail (8)
# Out:
#                 Country        Slug ISO2
# 240  Russian Federation      russia   RU
# 241               Chile       chile   CL
# 242               Spain       spain   ES
# 243           Sri Lanka   sri-lanka   LK
# 244              Canada      canada   CA
# 245              Kuwait      kuwait   KW
# 246               Libya       libya   LY
# 247          Seychelles  seychelles   SC

# %% [markdown]
# Para ver la información sobre las variables que contiene el dataframe se usa la siguiente función:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  248 non-null    object
#  1   Slug     248 non-null    object
#  2   ISO2     248 non-null    object
# dtypes: object(3)
# memory usage: 5.9+ KB

# %% [markdown]
# Para visualizar una sola de las variables se pone df y el nombre de la variable que quieras visualizar:

# %%
df["Slug"]
# Out:
# 0             angola
# 1            georgia
# 2            ireland
# 3           slovenia
# 4      french-guiana
#            ...
# 243        sri-lanka
# 244           canada
# 245           kuwait
# 246            libya
# 247       seychelles
# Name: Slug, Length: 248, dtype: object

# %% [markdown]
# ## Tiempo real
# La url que utilizaremos es  https://covid19api.com/countrt/colombia/status/confirmed/live
# Guardaremos los datos como hicimos anteriormente. Pondremos "df_es" para identificar el país, el ejemplo es el de España pero varia de acuerdo al país del que requiramos información. En este caso haremos la tabla de Ecuador, la de España y la de Argentina.

# %%
url_ec = 'https://api.covid19api.com/country/ecuador/status/confirmed/live'
df_ec = pd.read_json(url_ec)
df_ec
# Out:
#       Country CountryCode Province City CityCode   Lat    Lon    Cases  \
# 0     Ecuador          EC                        -1.83 -78.18        0
# 1     Ecuador          EC                        -1.83 -78.18        0
# 2     Ecuador          EC                        -1.83 -78.18        0
# 3     Ecuador          EC                        -1.83 -78.18        0
# 4     Ecuador          EC                        -1.83 -78.18        0
# ...       ...         ...      ...  ...      ...   ...    ...      ...
# 1035  Ecuador          EC                        -1.83 -78.18  1009958
# 1036  Ecuador          EC                        -1.83 -78.18  1009958
# 1037  Ecuador          EC                        -1.83 -78.18  1009958
# 1038  Ecuador          EC                        -1.83 -78.18  1009958
# 1039  Ecuador          EC                        -1.83 -78.18  1009958
#
#          Status                      Date
# 0     confirmed 2020-01-22 00:00:00+00:00
# 1     confirmed 2020-01-23 00:00:00+00:00
# 2     confirmed 2020-01-24 00:00:00+00:00
# 3     confirmed 2020-01-25 00:00:00+00:00
# 4     confirmed 2020-01-26 00:00:00+00:00
# ...         ...                       ...
# 1035  confirmed 2022-11-22 00:00:00+00:00
# 1036  confirmed 2022-11-23 00:00:00+00:00
# 1037  confirmed 2022-11-24 00:00:00+00:00
# 1038  confirmed 2022-11-25 00:00:00+00:00
# 1039  confirmed 2022-11-26 00:00:00+00:00
#
# [1040 rows x 10 columns]

# %% [markdown]
# ## Elaboración de un gráfico
# Para la elaboración del gráfico, el eje X será la fecha, y el eje Y los casos confirmados.
# Establecemos la fecha como la columna de control de este dataframe.

# %%
df_ec.set_index('Date')
# Out:
#                            Country CountryCode Province City CityCode   Lat  \
# Date
# 2020-01-22 00:00:00+00:00  Ecuador          EC                        -1.83
# 2020-01-23 00:00:00+00:00  Ecuador          EC                        -1.83
# 2020-01-24 00:00:00+00:00  Ecuador          EC                        -1.83
# 2020-01-25 00:00:00+00:00  Ecuador          EC                        -1.83
# 2020-01-26 00:00:00+00:00  Ecuador          EC                        -1.83
# ...                            ...         ...      ...  ...      ...   ...
# 2022-11-22 00:00:00+00:00  Ecuador          EC                        -1.83
# 2022-11-23 00:00:00+00:00  Ecuador          EC                        -1.83
# 2022-11-24 00:00:00+00:00  Ecuador          EC                        -1.83
# 2022-11-25 00:00:00+00:00  Ecuador          EC                        -1.83
# 2022-11-26 00:00:00+00:00  Ecuador          EC                        -1.83
#
#                              Lon    Cases     Status
# Date
# 2020-01-22 00:00:00+00:00 -78.18        0  confirmed
# 2020-01-23 00:00:00+00:00 -78.18        0  confirmed
# 2020-01-24 00:00:00+00:00 -78.18        0  confirmed
# 2020-01-25 00:00:00+00:00 -78.18        0  confirmed
# 2020-01-26 00:00:00+00:00 -78.18        0  confirmed
# ...                          ...      ...        ...
# 2022-11-22 00:00:00+00:00 -78.18  1009958  confirmed
# 2022-11-23 00:00:00+00:00 -78.18  1009958  confirmed
# 2022-11-24 00:00:00+00:00 -78.18  1009958  confirmed
# 2022-11-25 00:00:00+00:00 -78.18  1009958  confirmed
# 2022-11-26 00:00:00+00:00 -78.18  1009958  confirmed
#
# [1040 rows x 9 columns]

# %% [markdown]
# Le añado también los casos confirmados, con la siguiente fórmula:

# %%
df_ec.set_index ('Date')['Cases']
# Out:
# Date
# 2020-01-22 00:00:00+00:00          0
# 2020-01-23 00:00:00+00:00          0
# 2020-01-24 00:00:00+00:00          0
# 2020-01-25 00:00:00+00:00          0
# 2020-01-26 00:00:00+00:00          0
#                               ...
# 2022-11-22 00:00:00+00:00    1009958
# 2022-11-23 00:00:00+00:00    1009958
# 2022-11-24 00:00:00+00:00    1009958
# 2022-11-25 00:00:00+00:00    1009958
# 2022-11-26 00:00:00+00:00    1009958
# Name: Cases, Length: 1040, dtype: int64

# %% [markdown]
# Con estos datos creamos el gráfico con la función "plot", que significa que haga un gráfico.

# %%
df_ec.set_index('Date')['Cases'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Nombramos el gráfico con el atributo title para que quede completo.

# %%
df_ec.set_index('Date')['Cases'].plot(title="Casos de COVID19 en Ecuador")
# Out:
# <AxesSubplot:title={'center':'Casos de COVID19 en Ecuador'}, xlabel='Date'>

# %% [markdown]
# Ahora propondremos el siguiente País, España:

# %%
url_es = 'https://api.covid19api.com/country/spain/status/confirmed/live'
df_es = pd.read_json(url_es)
df_es
# Out:
#      Country CountryCode Province City CityCode    Lat   Lon     Cases  \
# 0      Spain          ES                         40.46 -3.75         0
# 1      Spain          ES                         40.46 -3.75         0
# 2      Spain          ES                         40.46 -3.75         0
# 3      Spain          ES                         40.46 -3.75         0
# 4      Spain          ES                         40.46 -3.75         0
# ...      ...         ...      ...  ...      ...    ...   ...       ...
# 1035   Spain          ES                         40.46 -3.75  13573721
# 1036   Spain          ES                         40.46 -3.75  13573721
# 1037   Spain          ES                         40.46 -3.75  13573721
# 1038   Spain          ES                         40.46 -3.75  13595504
# 1039   Spain          ES                         40.46 -3.75  13595504
#
#          Status                      Date
# 0     confirmed 2020-01-22 00:00:00+00:00
# 1     confirmed 2020-01-23 00:00:00+00:00
# 2     confirmed 2020-01-24 00:00:00+00:00
# 3     confirmed 2020-01-25 00:00:00+00:00
# 4     confirmed 2020-01-26 00:00:00+00:00
# ...         ...                       ...
# 1035  confirmed 2022-11-22 00:00:00+00:00
# 1036  confirmed 2022-11-23 00:00:00+00:00
# 1037  confirmed 2022-11-24 00:00:00+00:00
# 1038  confirmed 2022-11-25 00:00:00+00:00
# 1039  confirmed 2022-11-26 00:00:00+00:00
#
# [1040 rows x 10 columns]

# %%
df_es.set_index('Date')
# Out:
#                           Country CountryCode Province City CityCode    Lat  \
# Date
# 2020-01-22 00:00:00+00:00   Spain          ES                         40.46
# 2020-01-23 00:00:00+00:00   Spain          ES                         40.46
# 2020-01-24 00:00:00+00:00   Spain          ES                         40.46
# 2020-01-25 00:00:00+00:00   Spain          ES                         40.46
# 2020-01-26 00:00:00+00:00   Spain          ES                         40.46
# ...                           ...         ...      ...  ...      ...    ...
# 2022-11-22 00:00:00+00:00   Spain          ES                         40.46
# 2022-11-23 00:00:00+00:00   Spain          ES                         40.46
# 2022-11-24 00:00:00+00:00   Spain          ES                         40.46
# 2022-11-25 00:00:00+00:00   Spain          ES                         40.46
# 2022-11-26 00:00:00+00:00   Spain          ES                         40.46
#
#                             Lon     Cases     Status
# Date
# 2020-01-22 00:00:00+00:00 -3.75         0  confirmed
# 2020-01-23 00:00:00+00:00 -3.75         0  confirmed
# 2020-01-24 00:00:00+00:00 -3.75         0  confirmed
# 2020-01-25 00:00:00+00:00 -3.75         0  confirmed
# 2020-01-26 00:00:00+00:00 -3.75         0  confirmed
# ...                         ...       ...        ...
# 2022-11-22 00:00:00+00:00 -3.75  13573721  confirmed
# 2022-11-23 00:00:00+00:00 -3.75  13573721  confirmed
# 2022-11-24 00:00:00+00:00 -3.75  13573721  confirmed
# 2022-11-25 00:00:00+00:00 -3.75  13595504  confirmed
# 2022-11-26 00:00:00+00:00 -3.75  13595504  confirmed
#
# [1040 rows x 9 columns]

# %%
df_es.set_index ('Date')['Cases']
# Out:
# Date
# 2020-01-22 00:00:00+00:00           0
# 2020-01-23 00:00:00+00:00           0
# 2020-01-24 00:00:00+00:00           0
# 2020-01-25 00:00:00+00:00           0
# 2020-01-26 00:00:00+00:00           0
#                                ...
# 2022-11-22 00:00:00+00:00    13573721
# 2022-11-23 00:00:00+00:00    13573721
# 2022-11-24 00:00:00+00:00    13573721
# 2022-11-25 00:00:00+00:00    13595504
# 2022-11-26 00:00:00+00:00    13595504
# Name: Cases, Length: 1040, dtype: int64

# %%
df_es.set_index('Date')['Cases'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_es.set_index('Date')['Cases'].plot(title="Casos de COVID19 en España")
# Out:
# <AxesSubplot:title={'center':'Casos de COVID19 en España'}, xlabel='Date'>

# %% [markdown]
# Ahora continuaremos con Argentina:

# %%
url_ar = 'https://api.covid19api.com/country/argentina/status/confirmed/live'
df_ar = pd.read_json(url_ar)
df_ar
# Out:
#         Country CountryCode Province City CityCode    Lat    Lon    Cases  \
# 0     Argentina          AR                        -38.42 -63.62        0
# 1     Argentina          AR                        -38.42 -63.62        0
# 2     Argentina          AR                        -38.42 -63.62        0
# 3     Argentina          AR                        -38.42 -63.62        0
# 4     Argentina          AR                        -38.42 -63.62        0
# ...         ...         ...      ...  ...      ...    ...    ...      ...
# 1035  Argentina          AR                        -38.42 -63.62  9723924
# 1036  Argentina          AR                        -38.42 -63.62  9723924
# 1037  Argentina          AR                        -38.42 -63.62  9723924
# 1038  Argentina          AR                        -38.42 -63.62  9723924
# 1039  Argentina          AR                        -38.42 -63.62  9723924
#
#          Status                      Date
# 0     confirmed 2020-01-22 00:00:00+00:00
# 1     confirmed 2020-01-23 00:00:00+00:00
# 2     confirmed 2020-01-24 00:00:00+00:00
# 3     confirmed 2020-01-25 00:00:00+00:00
# 4     confirmed 2020-01-26 00:00:00+00:00
# ...         ...                       ...
# 1035  confirmed 2022-11-22 00:00:00+00:00
# 1036  confirmed 2022-11-23 00:00:00+00:00
# 1037  confirmed 2022-11-24 00:00:00+00:00
# 1038  confirmed 2022-11-25 00:00:00+00:00
# 1039  confirmed 2022-11-26 00:00:00+00:00
#
# [1040 rows x 10 columns]

# %%
df_ar.set_index('Date')
# Out:
#                              Country CountryCode Province City CityCode  \
# Date
# 2020-01-22 00:00:00+00:00  Argentina          AR
# 2020-01-23 00:00:00+00:00  Argentina          AR
# 2020-01-24 00:00:00+00:00  Argentina          AR
# 2020-01-25 00:00:00+00:00  Argentina          AR
# 2020-01-26 00:00:00+00:00  Argentina          AR
# ...                              ...         ...      ...  ...      ...
# 2022-11-22 00:00:00+00:00  Argentina          AR
# 2022-11-23 00:00:00+00:00  Argentina          AR
# 2022-11-24 00:00:00+00:00  Argentina          AR
# 2022-11-25 00:00:00+00:00  Argentina          AR
# 2022-11-26 00:00:00+00:00  Argentina          AR
#
#                              Lat    Lon    Cases     Status
# Date
# 2020-01-22 00:00:00+00:00 -38.42 -63.62        0  confirmed
# 2020-01-23 00:00:00+00:00 -38.42 -63.62        0  confirmed
# 2020-01-24 00:00:00+00:00 -38.42 -63.62        0  confirmed
# 2020-01-25 00:00:00+00:00 -38.42 -63.62        0  confirmed
# 2020-01-26 00:00:00+00:00 -38.42 -63.62        0  confirmed
# ...                          ...    ...      ...        ...
# 2022-11-22 00:00:00+00:00 -38.42 -63.62  9723924  confirmed
# 2022-11-23 00:00:00+00:00 -38.42 -63.62  9723924  confirmed
# 2022-11-24 00:00:00+00:00 -38.42 -63.62  9723924  confirmed
# 2022-11-25 00:00:00+00:00 -38.42 -63.62  9723924  confirmed
# 2022-11-26 00:00:00+00:00 -38.42 -63.62  9723924  confirmed
#
# [1040 rows x 9 columns]

# %%
df_ar.set_index ('Date')['Cases']
# Out:
# Date
# 2020-01-22 00:00:00+00:00          0
# 2020-01-23 00:00:00+00:00          0
# 2020-01-24 00:00:00+00:00          0
# 2020-01-25 00:00:00+00:00          0
# 2020-01-26 00:00:00+00:00          0
#                               ...
# 2022-11-22 00:00:00+00:00    9723924
# 2022-11-23 00:00:00+00:00    9723924
# 2022-11-24 00:00:00+00:00    9723924
# 2022-11-25 00:00:00+00:00    9723924
# 2022-11-26 00:00:00+00:00    9723924
# Name: Cases, Length: 1040, dtype: int64

# %%
df_ar.set_index('Date')['Cases'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_ar.set_index('Date')['Cases'].plot(title="Casos de COVID19 en Argentina")
# Out:
# <AxesSubplot:title={'center':'Casos de COVID19 en Argentina'}, xlabel='Date'>
